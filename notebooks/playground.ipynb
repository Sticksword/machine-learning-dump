# %%
import random
seed = 24

rng = random.Random(seed)

# %%
row_indices = list(range(5))
label_indices = list(range(5))
print(f"before: {row_indices=} {label_indices=}")

rng.shuffle(row_indices)
rng.shuffle(label_indices)
print(f"after: {row_indices=} {label_indices=}")
# Out:
# before: row_indices=[0, 1, 2, 3, 4] label_indices=[0, 1, 2, 3, 4]
# after: row_indices=[4, 2, 0, 1, 3] label_indices=[3, 0, 2, 4, 1]
